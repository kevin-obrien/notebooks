# %%
import erddapy
import pandas as pd
from datetime import datetime

# Define the ERDDAP server URL and dataset
server_url = 'https://gliders.ioos.us/erddap/'

# Create a connection to the ERDDAP server
e = erddapy.ERDDAP(server=server_url)

# %%
#grab glider IDs reporting in 2025
minTime="2025-01-01T00:00:00"
idURL = server_url + "tabledap/allDatasets.csv?datasetID&minTime>=" + minTime 
gliderIDs= pd.read_csv(idURL)

# %%
#cycle through glider list and pull out wmo_id, global attributes, and metadata about the instruments on the glider
for glider in gliderIDs['datasetID']:
    #glider = "amelia-20180501T0000"
    e.constraints = None
    e.protocol = "tabledap"
    e.dataset_id = glider
    info_url = e.get_info_url(dataset_id=glider, response="csv")
    #print(info_url)
    metadata= pd.read_csv(info_url)
    #metadata.head()
    globalAttributes = metadata[metadata['Variable Name'] == "NC_GLOBAL"]
    wmoURL = "https://gliders.ioos.us/erddap/tabledap/" + glider + ".csv?wmo_id"
    wmo = pd.read_csv(wmoURL)
    print("WMO ID: ", wmo.wmo_id.to_string(index=False))
    for attribute in (globalAttributes['Attribute Name']):
        print (attribute, ":" ,"".join(metadata.loc[metadata["Attribute Name"] == attribute , "Value"]))
    sensorVars = metadata[metadata['Attribute Name'] == "serial_number"]
    for vars in (sensorVars["Variable Name"]):
        var = metadata[metadata['Variable Name'] == vars]
        print ("variable name: ", vars)
        for attribute in (var["Attribute Name"].dropna()):
            print ("\t", attribute, ":", "".join(var.loc[var["Attribute Name"] == attribute , "Value"]))
# Out:
# WMO ID:  4801918
# _NCProperties : version=2,netcdf=4.8.1,hdf5=1.12.2
# acknowledgement : This work was supported by funding from NOAA/IOOS/SECOORA.
# cdm_data_type : TrajectoryProfile
# cdm_profile_variables : time_uv,lat_uv,lon_uv,u,v,profile_id,time,latitude,longitude
# cdm_trajectory_variables : trajectory,wmo_id
# comment : This is a 2025 SECOORA glider deploymentA trajectory is one deployment of a glider.Sequential profile number within the trajectory.  This value is unique in each file that is part of a single trajectory/deployment.Timestamp corresponding to the mid-point of the profile.Value is interpolated to provide an estimate of the latitude at the mid-point of the profile.Value is interpolated to provide an estimate of the longitude at the mid-point of the profile.unpumped CTDSlocum Glider USF BassSlocum Glider USF BassSlocum Glider USF BassSlocum Glider USF BassThe depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.Glider pressure transducer measured pressureLatitude measured using on-board GPS.  NMEA coordinates.Longitude measured using on-board GPS. NMEA coordinates.Dead-reckoned latitude calculated by the glider while underwater. NMEA coordinatesDead-reckoned longitude calculoned by the glider while underwater. NMEA coordinatesInterpolated latitude at each point in the time-seriesInterpolated longitude at each point in the time-seriesTimestamp at each point in the time-seriesThe Spectral Irradiance sensor measures the amount of radiation (light energy) per unit area that reaches a surface. Radiation is measured and reported separately for a series of wavelength bands, each between 10-20 nm wide.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.
# contributor_email : clembke@usf.edu
# contributor_name : Chad Lembke
# contributor_role : Principal Investigator
# contributor_url : https://www.marine.usf.edu
# Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# creator_email : dmac@secoora.org
# creator_name : SECOORA
# creator_url : https://secoora.org
# date_created : 2025-02-26T14:40:44Z
# date_issued : 2025-02-26T14:40:44Z
# date_modified : 2025-02-26T14:40:44Z
# Easternmost_Easting : -80.55232977554053
# featureType : TrajectoryProfile
# format_version : IOOS_Glider_NetCDF_v3.0-noqartod.nc
# geospatial_bounds : POLYGON ((31.341800 -80.660360, 31.341800 -80.659950, 31.341270 -80.659950, 31.341270 -80.660360, 31.341800 -80.660360))
# geospatial_lat_max : 31.382146860045147
# geospatial_lat_min : 30.02764964570442
# geospatial_lat_units : degrees_north
# geospatial_lon_max : -80.55232977554053
# geospatial_lon_min : -81.12181029853481
# geospatial_lon_units : degrees_east
# geospatial_vertical_max : 35.2831
# geospatial_vertical_min : 0.02979361
# geospatial_vertical_positive : down
# geospatial_vertical_units : m
# gts_ingest : true
# history : 2025-02-26T14:40:44Z - Created with the GUTILS package: https://github.com/SECOORA/GUTILS
# id : bass-20250203T00004801918
# infoUrl : https://gliders.ioos.us/erddap/
# institution : University of South Florida College of Marine Science Ocean Technology Group
# ioos_dac_checksum : e976bc63f992204f5a94c51affce03fc
# ioos_dac_completed : False
# ioos_regional_association : secoora
# keywords : AUVS > Autonomous Underwater Vehicles, Earth Science > Oceans > Ocean Pressure > Water Pressure, Earth Science > Oceans > Ocean Temperature > Water Temperature, Earth Science > Oceans > Salinity/Density > Conductivity, Earth Science > Oceans > Salinity/Density > Density, Earth Science > Oceans > Salinity/Density > Salinity, glider, In Situ Ocean-based platforms > Seaglider, Slocum, Spray, trajectory, underwater glider, water, wmo
# keywords_vocabulary : GCMD Science Keywords
# license : This data may be redistributed and used without restriction.
# Metadata_Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# naming_authority : edu.usf.marine
# Northernmost_Northing : 31.382146860045147
# platform_tags : portal:47,axds:portal:47:tag:Gliders
# platform_type : Slocum Glider
# processing_level : Dataset taken from glider native file format and is provided as is with no expressed or implied assurance of quality assurance or quality control.
# project : SECOORA Glider Observatory
# publisher_email : dmac@secoora.org
# publisher_name : SECOORA Glider Observatory
# publisher_url : https://secoora.org
# sea_name : North Atlantic Ocean
# source : Observational data from a profiling glider
# sourceUrl : (local files)
# Southernmost_Northing : 30.02764964570442
# standard_name_vocabulary : CF-v25
# subsetVariables : wmo_id,trajectory,profile_id,time,latitude,longitude
# summary : USF Bass Glider deployment in the North Atlantic Ocean
# support_email : dmac@secoora.org,ioos.glider.data@noaa.gov,ioos.glider.data@noaa.gov
# support_name : secoora,ioos,noaa
# support_role : fiscal,fiscal,fiscal
# support_type : ra,federal,federal
# time_coverage_duration : P0DT0H2M11.778870016S
# time_coverage_end : 2025-02-26T14:09:40Z
# time_coverage_start : 2025-02-03T15:20:41Z
# title : bass-20250203T0000
# Westernmost_Easting : -81.12181029853481
# variable name:  instrument_ctd
# 	 _FillValue : 0
# 	 calibration_date : 2022-06-09
# 	 comment : unpumped CTD
# 	 factory_calibrated : 2022-06-09
# 	 ioos_category : Identifier
# 	 long_name : CTD Metadata
# 	 make_model : Seabird WEBB Glider CTD
# 	 platform : platform
# 	 serial_number : 0126
# 	 type : instrument
# 	 units : 1
# 	 user_calibrated : 2022-06-09
# variable name:  instrument_dissolved_oxygen
# 	 _FillValue : 0
# 	 calibration_date : 2020-06-01
# 	 comment : Slocum Glider USF Bass
# 	 factory_calibrated : 2020-06-01
# 	 ioos_category : Other
# 	 long_name : Aanderaa Oxygen Optode 3835
# 	 make_model : Aanderaa 3835
# 	 platform : platform
# 	 serial_number : 0122
# 	 type : instrument
# variable name:  instrument_fluorometer
# 	 _FillValue : 0
# 	 calibration_date : 2020-06-01
# 	 comment : Slocum Glider USF Bass
# 	 factory_calibrated : 2020-06-01
# 	 ioos_category : Other
# 	 long_name : Wetlabs BBFL2SLO Flurometer
# 	 make_model : Wetlabs BBFL2SLO
# 	 platform : platform
# 	 serial_number : 0839
# 	 type : instrument
# variable name:  instrument_irradiance
# 	 _FillValue : 0
# 	 calibration_date : 2022-10-18
# 	 comment : Slocum Glider USF Bass
# 	 factory_calibrated : 2022-10-18
# 	 ioos_category : Other
# 	 long_name : Satlantic OCR507 ICSW Irradiance Sensor
# 	 make_model : Satlantic OCR507 ICSW
# 	 manual : https://www.seabird.com/asset-get.download.jsa?id=54627868877
# 	 platform : platform
# 	 serial_number : 0191
# 	 type : instrument
# variable name:  instrument_radiance
# 	 _FillValue : 0
# 	 calibration_date : 2022-10-18
# 	 comment : Slocum Glider USF Bass
# 	 factory_calibrated : 2022-10-18
# 	 ioos_category : Other
# 	 long_name : Satlantic OCR507R10W Radiance Sensor
# 	 make_model : Satlantic OCR507R10W
# 	 manual : https://www.seabird.com/asset-get.download.jsa?id=54627868877
# 	 platform : platform
# 	 serial_number : 0091
# 	 type : instrument
# WMO ID:  8901057
# _NCProperties : version=1|netcdflibversion=4.6.1|hdf5libversion=1.10.6
# acknowledgment : Funding provided by the National Science Foundation. Glider deployed by OOI Coastal Endurance personnel at Oregon State University
# cdm_data_type : TrajectoryProfile
# cdm_profile_variables : time_uv,lat_uv,lon_uv,u,v,profile_id,time,latitude,longitude
# cdm_trajectory_variables : trajectory,wmo_id
# comment : 2025-01-28 Deployed on the Newport Hydrographic line near the OOI Oregon Shelf mooring and destined to transit to the Grays Harbor Deep line via the 126 West line.A trajectory is one deployment of a glider.Sequential profile number within the trajectory. This value is unique in each file that is part of a single trajectory/deployment.Timestamp corresponding to the mid-point of the profile.Value is interpolated to provide an estimate of the latitude at the mid-point of the profile.Value is interpolated to provide an estimate of the longitude at the mid-point of the profile.Calculated from `pressure` and `latitude` using gsw.z_from_pInterpolated to all CTD timestamps to re-align realtime file decimation misalignmentsOxygen concentration has been compensated for salinity and pressure, but has not been corrected for the depth offset due to pitch of the glider and sensor offset from the CTD.pumped CTDOffset from pressure sensor = 0.917 mThe depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.m_pitch converted to degrees and forward filledInterpolated latitude at each point in the time-seriesInterpolated longitude at each point in the time-seriesTimestamp at each point in the time-seriesDerived from sci_water_pressure, converted from bar to dbar, and interpolated to science timestampsm_roll converted to degrees and forward filledName of the source data file and associated file metadataInterpolated to all CTD timestamps to re-align realtime file decimation misalignmentsThe depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.
# contributor_name : Edward Dever, Jonathan Fram, Stuart Pearce, Jonathan Whitefield, Christopher Wingard
# contributor_role : Endurance Array Principal Investigator/Project Scientist, Endurance Array Project Manager, Endurance Array Glider Lead, Endurance Array Glider Technician, Endurance Array Data Management
# Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# creator_email : stuart.pearce@oregonstate.edu
# creator_institution : OOI Coastal Endurance
# creator_name : Stuart Pearce
# creator_url : http://ceoas.oregonstate.edu/ooi/
# date_created : 2025-02-22T01:35:04Z
# date_issued : 2025-02-22T01:35:04Z
# date_modified : 2025-02-22T01:35:04Z
# deployment_datetime : 2025-01-28T20:07:00Z
# deployment_number : 0000200002
# Easternmost_Easting : -124.31304288612101
# featureType : TrajectoryProfile
# format_version : IOOS_Glider_NetCDF_v2.0.nc
# geospatial_lat_max : 46.98589832928261
# geospatial_lat_min : 44.562922961612635
# geospatial_lat_units : degrees_north
# geospatial_lon_max : -124.31304288612101
# geospatial_lon_min : -127.98362279002582
# geospatial_lon_units : degrees_east
# geospatial_vertical_max : 981.6434
# geospatial_vertical_min : -0.3074293
# geospatial_vertical_positive : down
# geospatial_vertical_units : m
# gts_ingest : true
# history : 2025-02-22T01:35:04Z: dataset created.
# hydrographic_line : Grays Harbor Deep
# id : ce_1153-20250128T2007ce_1153
# infoUrl : https://gliders.ioos.us/erddap/
# institution : OOI Coastal Endurance
# ioos_dac_checksum : 3f128fe12569b4ff0af51718a0b2de21
# ioos_dac_completed : False
# keywords : AUVS > Autonomous Underwater Vehicles, Earth Science > Oceans > Ocean Pressure > Water Pressure, Earth Science > Oceans > Ocean Temperature > Water Temperature, Earth Science > Oceans > Salinity/Density > Conductivity, Earth Science > Oceans > Salinity/Density > Density, Earth Science > Oceans > Salinity/Density > Salinity, glider, In Situ Ocean-based platforms > Seaglider, Slocum, Spray, trajectory, underwater glider, water, wmo
# keywords_vocabulary : GCMD Science Keywords
# license : All OOI data including data from OOI core sensors and all proposed sensors added\nby Principal Investigators, will be rapidly disseminated, open, and freely\navailable (within constraints of national security). Rapidly disseminated\nimplies that data will be made available as soon as technically feasible, but\ngenerally in near real-time, with latencies as small as seconds for the cabled\ncomponents. In limited cases, individual PIs who have developed a data source\nthat becomes part of the OOI network may request exclusive rights to the data\nfor a period of no more than one year from the onset of the data stream. The\nreliability, quality and completeness of data obtained through OOI are intended\nto be used in an education or research context. It is assumed that outages and\nerrors can occur and are dealt with by the users of the data. These data and\nsoftware are not for use in operational or decision-making settings. The OOI\nprogram makes reasonable efforts to ensure that the data provided are accurate.\nHowever, there may be no Quality Control (QC) performed on data acquired and\nprovided through the OOI program, and there may be no Quality Assurance (QA)\nprovided on information on those data sets. If QC/QA is performed, it is\ndescribed in the metadata.\n\nThe OOI program both produces and, through collaborations within the geosciences\ncommunity, gains access to data sets which may be redistributed either directly\nor indirectly at no cost and with no restrictions.\n\nWith regard to data distribution, all users must comply with any applicable U.S.\nexport laws and regulations. The OOI Program is not responsible for the use of\nthe data it provides. The full data policy is available at\nhttp://oceanobservatories.org/usage-policy.
# Metadata_Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# metadata_link : http://oceanobservatories.org/site/ce05moas/
# mode : rt
# naming_authority : org.oceanobservatories
# Northernmost_Northing : 46.98589832928261
# OOI_platform_type : OOI Coastal Endurance Array GliderOOI Coastal Endurance Array Glider
# OOI_reference_designator : CE05MOAS-G1153CE05MOAS-G1153
# platform_type : Slocum Glider
# processing_level : Raw Slocum Glider data. A few L2a processed variables. No QC performed
# program : Ocean Observatories Initiative
# project : Coastal Endurance Array
# publisher_email : help@oceanobservatories.org
# publisher_name : Ocean Observatories Initiative
# publisher_url : http://oceanobservatories.org
# raw_data_url : https://rawdata.oceanobservatories.org/files/CE05MOAS-G1153/D00002/
# references : http://oceanobservatories.org/https://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdf
# sea_name : Northeast Pacific Ocean
# source : Observational data from a profiling glider
# sourceUrl : (local files)
# Southernmost_Northing : 44.562922961612635
# standard_name_vocabulary : CF Standard Name Table v68
# subsetVariables : wmo_id,trajectory,profile_id,time,latitude,longitude
# summary : The Endurance Array is a multi-scaled array utilizing fixed and mobile assets to\nobserve cross-shelf and along-shelf variability in the coastal upwelling region\noff the Oregon and Washington coasts. The array also provides an extensive\nspatial footprint that encompasses a prototypical eastern boundary current\nregime and connectivity with the Cabled Array. OOI Coastal Glider deployments\nbridge the distances between the fixed sites of the Coastal Endurance Array and\nallow for adaptive sampling of the coastal waters of Washington and Oregon.\nThis dataset contains raw Slocum glider data parsed directly from the native\nglider file format. No corrections or other quality control algorithms have been\napplied.
# time_coverage_end : 2025-03-13T16:45:54Z
# time_coverage_start : 2025-01-28T20:18:48Z
# title : ce_1153-20250128T2007
# uuid : 7c74d91e-b06c-13de-e7d2-fd7f4b8388d6
# version : 1.0
# Westernmost_Easting : -127.98362279002582
# variable name:  instrument_ctd
# 	 _FillValue : 127
# 	 calibration_date : 2023-08-25T00:00:00Z
# 	 comment : pumped CTD
# 	 factory_calibrated : 2023-08-25T00:00:00Z
# 	 ioos_category : Identifier
# 	 long_name : CTD Metadata
# 	 make_model : Sea-Bird GPCTD
# 	 OOI_series : CTDGV-M
# 	 platform : platform
# 	 serial_number : 9977
# 	 service_id : TWR:R151359
# 	 type : platform
# 	 units : 1
# variable name:  instrument_flbbcd
# 	 _FillValue : -2147483647
# 	 calibration_date : 2023-08-15T00:00:00Z
# 	 factory_calibrated : 2023-08-15T00:00:00Z
# 	 ioos_category : Other
# 	 long_name : Optical Backscatter, Chlorophyll and CDOM Fluorescence Sensor
# 	 make_model : Sea-Bird/WET Labs ECO Puck FLBBCD-SLC
# 	 OOI_series : FLORT-M
# 	 platform : platform
# 	 serial_number : 8440
# 	 service_id : TWR:R151359
# 	 type : instrument
# variable name:  instrument_oxygen
# 	 _FillValue : -2147483647
# 	 calibration_date : 2024-06-10T00:00:00Z
# 	 comment : Offset from pressure sensor = 0.917 m
# 	 factory_calibrated : 2024-06-10T00:00:00Z
# 	 ioos_category : Other
# 	 long_name : Dissolved Oxygen Sensor
# 	 make_model : Aanderaa Optode 4831
# 	 offset_from_depth_sensor : 0.917m
# 	 OOI_series : DOSTA-M
# 	 platform : platform
# 	 serial_number : 570
# 	 service_id : YSI:367450
# 	 type : instrument
# variable name:  instrument_par
# 	 _FillValue : -2147483647
# 	 calibration_date : 2023-12-06T00:00:00Z
# 	 factory_calibrated : 2023-12-06T00:00:00Z
# 	 ioos_category : Other
# 	 long_name : Photosynthetically Active Radiation (PAR) Sensor
# 	 make_model : Biospherical QSP-2155
# 	 OOI_series : PARAD-M
# 	 platform : platform
# 	 serial_number : 50397
# 	 service_id : TWR:R151359
# 	 type : instrument
# WMO ID:  4801967
# _NCProperties : version=1|netcdflibversion=4.6.1|hdf5libversion=1.10.6
# acknowledgment : Funding provided by the National Science Foundation. Glider deployed by OOI Coastal Endurance personnel at Oregon State University
# cdm_data_type : TrajectoryProfile
# cdm_profile_variables : time_uv,lat_uv,lon_uv,u,v,profile_id,time,latitude,longitude
# cdm_trajectory_variables : trajectory,wmo_id
# comment : 2025-01-28 Deployed on the Newport Hydrographic Shallow line near the OOI Oregon Shelf mooring.A trajectory is one deployment of a glider.Sequential profile number within the trajectory. This value is unique in each file that is part of a single trajectory/deployment.Timestamp corresponding to the mid-point of the profile.Value is interpolated to provide an estimate of the latitude at the mid-point of the profile.Value is interpolated to provide an estimate of the longitude at the mid-point of the profile.Calculated from `pressure` and `latitude` using gsw.z_from_pInterpolated to all CTD timestamps to re-align realtime file decimation misalignmentsOxygen concentration has been compensated for salinity and pressure, but has not been corrected for the depth offset due to pitch of the glider and sensor offset from the CTD.pumped CTDOffset from pressure sensor = 0.917 mThe depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.m_pitch converted to degrees and forward filledInterpolated latitude at each point in the time-seriesInterpolated longitude at each point in the time-seriesTimestamp at each point in the time-seriesDerived from sci_water_pressure, converted from bar to dbar, and interpolated to science timestampsm_roll converted to degrees and forward filledName of the source data file and associated file metadataInterpolated to all CTD timestamps to re-align realtime file decimation misalignmentsThe depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater. The value is calculated over the entire underwater segment, which may consist of 1 or more dives.
# contributor_name : Edward Dever, Jonathan Fram, Stuart Pearce, Jonathan Whitefield, Christopher Wingard
# contributor_role : Endurance Array Principal Investigator/Project Scientist, Endurance Array Project Manager, Endurance Array Glider Lead, Endurance Array Glider Technician, Endurance Array Data Management
# Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# creator_email : stuart.pearce@oregonstate.edu
# creator_institution : OOI Coastal Endurance
# creator_name : Stuart Pearce
# creator_url : http://ceoas.oregonstate.edu/ooi/
# date_created : 2025-02-22T01:34:08Z
# date_issued : 2025-02-22T01:34:08Z
# date_modified : 2025-02-22T01:34:08Z
# deployment_datetime : 2025-01-28T19:07:00Z
# deployment_number : 0001600016
# Easternmost_Easting : -124.09366811816845
# featureType : TrajectoryProfile
# format_version : IOOS_Glider_NetCDF_v2.0.nc
# geospatial_lat_max : 44.88601566389368
# geospatial_lat_min : 44.36529726247981
# geospatial_lat_units : degrees_north
# geospatial_lon_max : -124.09366811816845
# geospatial_lon_min : -124.99190458751451
# geospatial_lon_units : degrees_east
# geospatial_vertical_max : 193.4026
# geospatial_vertical_min : -0.2083018
# geospatial_vertical_positive : down
# geospatial_vertical_units : m
# gts_ingest : true
# history : 2025-02-22T01:34:08Z: dataset created.
# hydrographic_line : Newport Hydrographic Shallow
# id : ce_382-20250128T1907ce_382
# infoUrl : https://gliders.ioos.us/erddap/
# institution : OOI Coastal Endurance
# ioos_dac_checksum : a1a0d8aea5a67ebd672358e010faf84c
# ioos_dac_completed : False
# keywords : AUVS > Autonomous Underwater Vehicles, Earth Science > Oceans > Ocean Pressure > Water Pressure, Earth Science > Oceans > Ocean Temperature > Water Temperature, Earth Science > Oceans > Salinity/Density > Conductivity, Earth Science > Oceans > Salinity/Density > Density, Earth Science > Oceans > Salinity/Density > Salinity, glider, In Situ Ocean-based platforms > Seaglider, Slocum, Spray, trajectory, underwater glider, water, wmo
# keywords_vocabulary : GCMD Science Keywords
# license : All OOI data including data from OOI core sensors and all proposed sensors added\nby Principal Investigators, will be rapidly disseminated, open, and freely\navailable (within constraints of national security). Rapidly disseminated\nimplies that data will be made available as soon as technically feasible, but\ngenerally in near real-time, with latencies as small as seconds for the cabled\ncomponents. In limited cases, individual PIs who have developed a data source\nthat becomes part of the OOI network may request exclusive rights to the data\nfor a period of no more than one year from the onset of the data stream. The\nreliability, quality and completeness of data obtained through OOI are intended\nto be used in an education or research context. It is assumed that outages and\nerrors can occur and are dealt with by the users of the data. These data and\nsoftware are not for use in operational or decision-making settings. The OOI\nprogram makes reasonable efforts to ensure that the data provided are accurate.\nHowever, there may be no Quality Control (QC) performed on data acquired and\nprovided through the OOI program, and there may be no Quality Assurance (QA)\nprovided on information on those data sets. If QC/QA is performed, it is\ndescribed in the metadata.\n\nThe OOI program both produces and, through collaborations within the geosciences\ncommunity, gains access to data sets which may be redistributed either directly\nor indirectly at no cost and with no restrictions.\n\nWith regard to data distribution, all users must comply with any applicable U.S.\nexport laws and regulations. The OOI Program is not responsible for the use of\nthe data it provides. The full data policy is available at\nhttp://oceanobservatories.org/usage-policy.
# Metadata_Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# metadata_link : http://oceanobservatories.org/site/ce05moas/
# mode : rt
# naming_authority : org.oceanobservatories
# Northernmost_Northing : 44.88601566389368
# OOI_platform_type : OOI Coastal Endurance Array GliderOOI Coastal Endurance Array Glider
# OOI_reference_designator : CE05MOAS-GL382CE05MOAS-GL382
# platform_type : Slocum Glider
# processing_level : Raw Slocum Glider data. A few L2a processed variables. No QC performed
# program : Ocean Observatories Initiative
# project : Coastal Endurance Array
# publisher_email : help@oceanobservatories.org
# publisher_name : Ocean Observatories Initiative
# publisher_url : http://oceanobservatories.org
# raw_data_url : https://rawdata.oceanobservatories.org/files/CE05MOAS-GL382/D00016/
# references : http://oceanobservatories.org/https://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdfhttps://gliders.ioos.us/files/Manual-for-QC-of-Glider-Data_05_09_16.pdf
# sea_name : Northeast Pacific Ocean
# source : Observational data from a profiling glider
# sourceUrl : (local files)
# Southernmost_Northing : 44.36529726247981
# standard_name_vocabulary : CF Standard Name Table v68
# subsetVariables : wmo_id,trajectory,profile_id,time,latitude,longitude
# summary : The Endurance Array is a multi-scaled array utilizing fixed and mobile assets to\nobserve cross-shelf and along-shelf variability in the coastal upwelling region\noff the Oregon and Washington coasts. The array also provides an extensive\nspatial footprint that encompasses a prototypical eastern boundary current\nregime and connectivity with the Cabled Array. OOI Coastal Glider deployments\nbridge the distances between the fixed sites of the Coastal Endurance Array and\nallow for adaptive sampling of the coastal waters of Washington and Oregon.\nThis dataset contains raw Slocum glider data parsed directly from the native\nglider file format. No corrections or other quality control algorithms have been\napplied.
# time_coverage_end : 2025-03-13T20:52:03Z
# time_coverage_start : 2025-01-28T19:24:19Z
# title : ce_382-20250128T1907
# uuid : 8ffa37a9-2bdb-a087-e6a6-1a9c0e4c2593
# version : 1.0
# Westernmost_Easting : -124.99190458751451
# variable name:  instrument_ctd
# 	 _FillValue : 127
# 	 calibration_date : 2024-04-02T00:00:00Z
# 	 comment : pumped CTD
# 	 factory_calibrated : 2024-04-02T00:00:00Z
# 	 ioos_category : Identifier
# 	 long_name : CTD Metadata
# 	 make_model : Sea-Bird GPCTD
# 	 OOI_series : CTDGV-M
# 	 platform : platform
# 	 serial_number : 9082
# 	 service_id : TWR:10066
# 	 type : platform
# 	 units : 1
# variable name:  instrument_flbbcd
# 	 _FillValue : -2147483647
# 	 calibration_date : 2024-03-18T00:00:00Z
# 	 factory_calibrated : 2024-03-18T00:00:00Z
# 	 ioos_category : Other
# 	 long_name : Optical Backscatter, Chlorophyll and CDOM Fluorescence Sensor
# 	 make_model : Sea-Bird/WET Labs ECO Puck FLBBCD-SLC
# 	 OOI_series : FLORT-M
# 	 platform : platform
# 	 serial_number : 4473
# 	 service_id : TWR:10066
# 	 type : instrument
# variable name:  instrument_oxygen
# 	 _FillValue : -2147483647
# 	 calibration_date : 2023-08-14T00:00:00Z
# 	 comment : Offset from pressure sensor = 0.917 m
# 	 factory_calibrated : 2023-08-14T00:00:00Z
# 	 ioos_category : Other
# 	 long_name : Dissolved Oxygen Sensor
# 	 make_model : Aanderaa Optode 4831
# 	 offset_from_depth_sensor : 0.917m
# 	 OOI_series : DOSTA-M
# 	 platform : platform
# 	 serial_number : 864
# 	 service_id : YSI:362640
# 	 type : instrument
# variable name:  instrument_par
# 	 _FillValue : -2147483647
# 	 calibration_date : 2024-04-05T00:00:00Z
# 	 factory_calibrated : 2024-04-05T00:00:00Z
# 	 ioos_category : Other
# 	 long_name : Photosynthetically Active Radiation (PAR) Sensor
# 	 make_model : Biospherical QSP-2155
# 	 OOI_series : PARAD-M
# 	 platform : platform
# 	 serial_number : 50165
# 	 service_id : TWR:10066
# 	 type : instrument
# WMO ID:  4802956
# _NCProperties : version=2,netcdf=4.8.1,hdf5=1.12.2
# acknowledgement : This work was supported by funding from the Broad Reach Fund, with support from NOAA/IOOS/SECOORA.
# cdm_data_type : TrajectoryProfile
# cdm_profile_variables : time_uv,lat_uv,lon_uv,u,v,profile_id,time,latitude,longitude
# cdm_trajectory_variables : trajectory,wmo_id
# comment : This is a 2025 right whale monitoring mission.A trajectory is one deployment of a glider.Sequential profile number within the trajectory.  This value is unique in each file that is part of a single trajectory/deployment.Timestamp corresponding to the mid-point of the profile.Value is interpolated to provide an estimate of the latitude at the mid-point of the profile.Value is interpolated to provide an estimate of the longitude at the mid-point of the profile.Slocum Glider SkIO Franklin -- unpumped RBR CTDSlocum Glider SkIO FranklinSlocum Glider SkIO FranklinThe depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.Glider pressure transducer measured pressureLatitude measured using on-board GPS.  NMEA coordinates.Longitude measured using on-board GPS. NMEA coordinates.Dead-reckoned latitude calculated by the glider while underwater. NMEA coordinatesDead-reckoned longitude calculoned by the glider while underwater. NMEA coordinatesInterpolated latitude at each point in the time-seriesInterpolated longitude at each point in the time-seriesTimestamp at each point in the time-seriesThe depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.
# contributor_email : catherine.edwards@skio.uga.edu
# contributor_name : Catherine Edwards
# contributor_role : Principal Investigator
# contributor_url : http://www.marsci.uga.edu/directory/catherine-r-edwards
# Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# creator_email : dmac@secoora.org
# creator_name : SECOORA Glider Observatory
# creator_url : https://secoora.org
# date_created : 2025-02-08T21:30:53Z
# date_issued : 2025-02-08T21:30:53Z
# date_modified : 2025-02-08T21:30:53Z
# Easternmost_Easting : -80.60011398508422
# featureType : TrajectoryProfile
# format_version : IOOS_Glider_NetCDF_v3.0-noqartod.nc
# geospatial_bounds : POLYGON ((30.448470 -81.162450, 30.448470 -81.162450, 30.448290 -81.162450, 30.448290 -81.162450, 30.448470 -81.162450))
# geospatial_lat_max : 31.202335117690133
# geospatial_lat_min : 29.88012119494789
# geospatial_lat_units : degrees_north
# geospatial_lon_max : -80.60011398508422
# geospatial_lon_min : -81.20669479349655
# geospatial_lon_units : degrees_east
# geospatial_vertical_max : 27.04466
# geospatial_vertical_min : 1.05715
# geospatial_vertical_positive : down
# geospatial_vertical_units : m
# gts_ingest : true
# history : 2025-02-08T21:30:53Z - Created with the GUTILS package: https://github.com/SECOORA/GUTILS
# id : franklin-20250102T00004802956
# infoUrl : https://gliders.ioos.us/erddap/
# institution : Skidaway Institute of Oceanography
# ioos_dac_checksum : 53892ac89ad46c0f561ee7f05f3fbfd4
# ioos_dac_completed : False
# ioos_regional_association : secoora
# keywords : AUVS > Autonomous Underwater Vehicles, Earth Science > Oceans > Ocean Pressure > Water Pressure, Earth Science > Oceans > Ocean Temperature > Water Temperature, Earth Science > Oceans > Salinity/Density > Conductivity, Earth Science > Oceans > Salinity/Density > Density, Earth Science > Oceans > Salinity/Density > Salinity, glider, In Situ Ocean-based platforms > Seaglider, Slocum, Spray, trajectory, underwater glider, water, wmo
# keywords_vocabulary : GCMD Science Keywords
# license : This data may be redistributed and used without restriction.
# Metadata_Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# naming_authority : edu.uga.skio
# Northernmost_Northing : 31.202335117690133
# platform_tags : portal:47,axds:portal:47:tag:Gliders
# platform_type : Slocum Glider
# processing_level : Dataset taken from glider native file format and is provided as is with no expressed or implied assurance of quality assurance or quality control.
# project : SkIO/USC Right Whale Monitoring in SE Calving Grounds
# publisher_email : dmac@secoora.org
# publisher_name : SECOORA Glider Observatory
# publisher_url : https://secoora.org
# sea_name : North Atlantic Ocean
# source : Observational data from a profiling glider
# sourceUrl : (local files)
# Southernmost_Northing : 29.88012119494789
# standard_name_vocabulary : CF-v25
# subsetVariables : wmo_id,trajectory,profile_id,time,latitude,longitude
# summary : SKIO Franklin Glider deployment in the North Atlantic Ocean (January 2025)
# support_email : dmac@secoora.org,ioos.glider.data@noaa.gov,ioos.glider.data@noaa.gov
# support_name : secoora,ioos,noaa
# support_role : fiscal,fiscal,fiscal
# support_type : ra,federal,federal
# time_coverage_duration : P0DT0H1M13.071929856S
# time_coverage_end : 2025-02-08T21:13:38Z
# time_coverage_start : 2025-01-02T16:28:12Z
# title : franklin-20250102T0000
# Westernmost_Easting : -81.20669479349655
# WMO ID:  8901079
# _NCProperties : version=1|netcdflibversion=4.6.1|hdf5libversion=1.10.3
# acknowledgment : This deployment supported by New York State Energy Research and Development Authority (NYSERDA) Agreement 184660
# cdm_data_type : TrajectoryProfile
# cdm_profile_variables : time_uv,lat_uv,lon_uv,u,v,profile_id,time,latitude,longitude
# cdm_trajectory_variables : trajectory,wmo_id
# comment : Deployed by Charles Flagg and Lucas Merlo with Captain Jim Reynolds on TowboatUS out of Fire Island, NY.A trajectory is one deployment of a glider.Unique identifier of the profile. The profile ID is the mean profile timestampTimestamp corresponding to the mid-point of the profile.Value is interpolated to provide an estimate of the latitude at the mid-point of the profile.Value is interpolated to provide an estimate of the longitude at the mid-point of the profile.Calculated from llat_pressure and llat_latitude using gsw.z_from_pNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameDead-reckoned latitude. Units are degrees decimal minutesDead-reckoned longitude. Units are degrees decimal minutesNative glider sensor nameNative glider sensor nameNative glider sensor nameGPS latitude. Units are degrees decimal minutesGPS longitude. Units are degrees decimal minutesPumpedNo calibration date. No NVS instrument definition (https://vocab.nerc.ac.uk/collection/L22/current/) as of 2024-07-15.Chlorophyll a,beta700nm,CDOMModel 4831The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.Native glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameCTD depth plus altitude off the bottomNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameInterpolated latitude at each point in the time-seriesInterpolated longitude at each point in the time-seriesTimestamp at each point in the time-seriesConverted from bar to decibarName of the source data file and associated file metadataThe depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.Native glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative glider sensor nameNative gl ...
# contributor_name : Lesley Thorne,Joseph Warren,Jacqueline McSweeney,Josh Kohut,Travis Miles,Mark Baumgartner,Charles Flagg,Katie Gallagher,John Kerfoot,Laura Nazzaro,Lori Garzio
# contributor_role : Principal Investigator,Principal Investigator,Principal Investigator,Principal Investigator,Principal Investigator,Principal Investigator,Principal Investigator Pilot and Data Management,Glider Pilot,Data Management,Data Management,Data Management
# Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# creator_email : gliderdata@marine.rutgers.edu
# creator_institution : Rutgers University
# creator_name : Rutgers Center for Ocean Observing Leadership Glider Data Team
# creator_type : group
# creator_url : https://rucool.marine.rutgers.edu
# date_created : 2025-02-11T16:00:11Z
# date_issued : 2025-02-11T16:00:11Z
# date_modified : 2025-02-11T16:00:11Z
# deployment : maracoos_06-20250116T1522
# Easternmost_Easting : -72.63576527011412
# featureType : TrajectoryProfile
# geospatial_bounds : POLYGON ((39.31090666666667 -74.3481384384496, 39.31090666666667 -74.346605, 39.30982527457056 -74.346605, 39.30982527457056 -74.3481384384496, 39.31090666666667 -74.3481384384496))
# geospatial_bounds_crs : EPSG:4326
# geospatial_bounds_vertical_crs : EPSG:5831
# geospatial_lat_max : 40.56469773804081
# geospatial_lat_min : 39.16973201462615
# geospatial_lat_resolution : 0.00001 degree
# geospatial_lat_units : degrees_north
# geospatial_lon_max : -72.63576527011412
# geospatial_lon_min : -74.3471149365652
# geospatial_lon_resolution : 0.00001 degree
# geospatial_lon_units : degrees_east
# geospatial_vertical_max : 69.34338
# geospatial_vertical_min : 0.1290093
# geospatial_vertical_positive : down
# geospatial_vertical_resolution : 0
# geospatial_vertical_units : m
# gts_ingest : True
# history : 2025-02-11T16:00:11Z: /tmp/tmpnow1m2in/maracoos_06_20250211T121608Z_rt8pj8ulmv.nc created\n2025-02-11T16:00:11Z: /home/kerfoot/code/gncutils/scripts/dba_to_profile_nc.py /home/coolgroup/slocum/deployments/2025/maracoos_06-20250116T1522/data/in/ascii/queue/maracoos_06_2025_041_1_8_sbd.dat\n
# id : maracoos_06-20250116T1522maracoos_06
# infoUrl : https://gliders.ioos.us/erddap/
# institution : Stony Brook University
# instrument : In Situ/Laboratory Instruments > Profilers/Sounders > CTDinstrument_ctdinstrument_ctdinstrument_ctdinstrument_ctdinstrument_ctdinstrument_ctdinstrument_ctdinstrument_ctd
# instrument_vocabulary : NASA/GCMD Instrument Keywords Version 8.5
# ioos_dac_checksum : 0952256178bcccbe29454f9acbb05c99
# ioos_dac_completed : True
# keywords : AUVS > Autonomous Underwater Vehicles, Earth Science > Oceans > Ocean Pressure > Water Pressure, Earth Science > Oceans > Ocean Temperature > Water Temperature, Earth Science > Oceans > Salinity/Density > Conductivity, Earth Science > Oceans > Salinity/Density > Density, Earth Science > Oceans > Salinity/Density > Salinity, glider, In Situ Ocean-based platforms > Seaglider, Slocum, Spray, trajectory, underwater glider, water, wmo
# keywords_vocabulary : GCMD Science Keywords
# license : This data may be redistributed and used without restriction.  Data provided as is with no expressed or implied assurance of quality assurance or quality control
# Metadata_Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# naming_authority : edu.rutgers.rucool
# ncei_template_version : NCEI_NetCDF_Trajectory_Template_v2.0
# Northernmost_Northing : 40.56469773804081
# platform : In Situ Ocean-based Platforms > AUVS > Autonomous Underwater ...
# platform_type : Slocum Glider
# platform_vocabulary : NASA/GCMD Platforms Keywords Version 8.5
# processing_level : Raw Slocum glider time-series dataset from the native data file format. No quality control provided.2222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222222
# product_version : 1.0
# program : NYSERDA Acoustic and oceanographic surveys to support offshore wind energy development
# project : Glider based ecological and oceanographic surveys of the New York Bight (GLIDE)
# publisher_email : gliderdata@marine.rutgers.edu
# publisher_institution : Rutgers University
# ...
# sourceUrl : (local files)
# Southernmost_Northing : 40.932501320967056
# standard_name_vocabulary : CF Standard Name Table v27
# subsetVariables : wmo_id,trajectory,profile_id,time,latitude,longitude
# summary : This project is using a JASCO OceanObserver Snout hydrophone attached to a glider to monitor and understand the spatial and temporal distribution of spawning cod aggregations in the Revolution Wind and Sunrise Wind offshore wind lease areas during the spawning season. These glider-based observations are occurring during construction activities that may include seabed preparation along cable routes and placement of scour protection at the foundation locations. The glider is also equipped with a CTD and a VEMCO receiver. This is the fourth of four sequential deployments planned to monitor the wind lease area for five months during cod spawning season, November through March.
# time_coverage_duration : PT03M25S
# time_coverage_end : 2025-03-11T11:36:50Z
# time_coverage_resolution : PT03S
# time_coverage_start : 2025-02-24T14:08:21Z
# title : unit_1190-20250224T1405
# uuid : 110579a9-74bc-4191-a829-6c1c8305558e
# Westernmost_Easting : -71.39859400448637
# wmo_platform_code : 89011188901118
# variable name:  instrument_hydrophone
# 	 _FillValue : -2147483647
# 	 calibration_date : 2024-11-13
# 	 comment : 4 x M36-V35-100 hydrophone. Strap on instrument, no data flow through glider. No NVS vocabulary as of 2024-12-17; description is a modified version of standard OceanObserver instrument (https://vocab.nerc.ac.uk/collection/L22/current/TOOL1894/) modified based on ObserverSnout manufacturer page (https://vocab.nerc.ac.uk/collection/L22/current/TOOL1894/).
# 	 description : A submersible real-time acoustic monitoring system for marine mammal detection, identification, and localisation, ambient and vessel noise quantification, and wind and tidal energy monitoring. The JASCO OceanObserver-Snout has applications on drifters, acoustic profiling floats, gliders, buoys, and other autonomous vehicles. The OceanObserver system records the underwater sounds while running automated cetacean detectors that flag possible marine mammal calls or other events of interest by use of onboard detection algorithms tailored to species and call types of choice, as part of JASCO's PAMlab INT (integrated) software. Features local and global data telemetry via Wi-Fi, VHF, Iridium, cellular, serial, Ethernet, or acoustic modem, and wireless control via Wi-Fi or Bluetooth. For bandwidth-limited telemetry like cellular and Iridium, the OceanObserver converts the detection spectrograms into frequency contours and ranks them by priority. The events are relayed via satellite and delivered by email. The processed events are prioritised so that important events, like detections of species at risk, are sent first, making best use of the communication window. The OceanObserver was designed with modular components to tailor the system to the application, and up to 12 TB memory capacity on removable SD cards. The system features up to 4 mid-speed acoustic channels at 8 - 512 ksps. Spectra noise floor is better than -150 dB re FS per square root Hz at 8 - 512 ksps or better than -145 dB re FS per square root Hz at 2048 ksps. Standard hydrophone sensitivities are -164 dB re 1 V/\u03bcPa at 1 kHz or -210 dB re 1 V/\u03bcPa at 1 kHz.
# 	 factory_calibrated : 2024-11-13
# 	 ioos_category : Other
# 	 long_name : JASCO OceanObserver-Snout acoustic monitoring system
# 	 maker : JASCO Applied Sciences
# 	 maker_vocabulary : https://vocab.nerc.ac.uk/collection/L35/current/MAN0245/
# 	 model : JASCO OceanObserver-Snout
# 	 owner : JASCO Applied Sciences
# 	 references : https://www.jasco.com/oceanobserver-slocum-glider, https://www.jasco.com/-oceanobserver-snout
# 	 serial_number : 1138
# 	 type : hydrophones
# 	 type_vocabulary : https://vocab.nerc.ac.uk/collection/L05/current/369/
# variable name:  instrument_rbrctd
# 	 _FillValue : -2147483647
# 	 calibration_date : 2024-05-30
# 	 description : A conductivity, temperature and pressure sensor designed for use on gliders and autonomous underwater vehicles (AUVs). It can be used to derive salinity, density and sound velocity and is optimised for turbulence measurements and passive acoustic monitoring due to its silent operation (non-pumped). The instrument is available as two configurations; the standard RBR Legato3 has a 2 Hz standard thermistor response; the RBR Legato3 Fast 16 instrument has a 16 Hz fast thermistor response. Additional sensors such as dissolved oxygen, fluorescence, turbidity, and PAR are all supported. The RBR Legato3 is designed to fit into a standard 2 x 7 inch sensor bay, with both wet- and dry-bay models. The RBR Legato3 is depth-rated to 1000m, with a pressure range from 500-1000 db and accuracy of +/- 0.05 percent (full scale). The conductivity accuracy is +/- 0.003 mS/cm. Temperature range is -5 degC to +42 degC (ITS-90) with an accuracy of +/- 0.002 degC (-5 to +35 degC) and +/- 0.004 degC (+35 to +42 degC).
# 	 factory_calibrated : 2024-05-30
# 	 ioos_category : Other
# 	 long_name : RBR Legato3 CTD
# 	 maker : RBR
# 	 maker_vocabulary : https://vocab.nerc.ac.uk/collection/L35/current/MAN0049/,https://vocab.nerc.ac.uk/collection/B75/current/ORG00299/
# 	 model : RBR Legato3 CTD
# 	 model_vocabulary : https://vocab.nerc.ac.uk/collection/L22/current/TOOL1745/
# 	 owner : JASCO Applied Sciences
# 	 serial_number : 233237
# 	 type : CTD,salinity sensor,water temperature sensor,water pressure sensor
# 	 type_vocabulary : https://vocab.nerc.ac.uk/collection/L05/current/130/,https://vocab.nerc.ac.uk/collection/L05/current/350/,https://vocab.nerc.ac.uk/collection/L05/current/134/,https://vocab.nerc.ac.uk/collection/L05/current/WPS/
# variable name:  instrument_vmt
# 	 _FillValue : -2147483647
# 	 calibration_date : 1970-01-01
# 	 comment : No calibration date. No NVS vocabulary for instrument as of 2023-04-20. VMT transmits with ID 59963.
# 	 description : The Vemco Mobile Transceiver (VMT) is a hybrid between a 69 kHz coded transmitter and a 69 kHz monitoring receiver (similar to the VR2W-69 kHz). The VMT is externally attached to an animal or glider and its receiving capabilities enable it to detect other animals that have been tagged with a 69 kHz coded transmitter. Coded transmitting capabilities also allow the VMT to be detected by other deployed 69 kHz receivers. The VMT comes with several user programmable options such as the ability to vary receiver ON time (duty cycle), as well as some tag programming options. Depth rated to 1000 m.
# 	 factory_calibrated : 1970-01-01
# 	 ioos_category : Other
# 	 long_name : Vemco Mobile Transceiver (VMT)
# 	 maker : Innovasea Systems Inc.,VEMCO
# 	 maker_vocabulary : https://vocab.nerc.ac.uk/collection/L35/current/MAN0207/,https://vocab.nerc.ac.uk/collection/B75/current/ORG00348/
# 	 model : VMT
# 	 owner : Rutgers University
# 	 references : https://www.innovasea.com/wp-content/uploads/2021/06/Innovasea-Fish-Tracking-vmt-data-sheet-0621.pdf
# 	 serial_number : 1502894
# 	 type : tracking tags
# 	 type_vocabulary : https://vocab.nerc.ac.uk/collection/L05/current/TRTG/
# variable name:  platform_meta
# 	 _FillValue : 127
# 	 depth_rating : 100m
# 	 description : A long-range autonomous underwater vehicle (AUV) based on buoyancy. The G3S utilises the same features as the G3 glider but uses a new STM32 Processor. This replaces the Persistor processor used on the G3 glider in the Science and Flight Bays. The G3S is used for remote water column sampling. It uses hydraulic buoyancy change to alter the vehicle density in relation to the surrounding water thereby causing the vehicle to either float or sink. Given an appropriate dive or climb angle, the wings and body lift and convert some of this vertical motion into a forward saw tooth horizontal motion. Periodically, the glider surfaces and calls via Iridium Satellite Phone (anywhere in world) or Free Wave RF Modem (line of sight) in to Dockserver (auto attendant computer) to relay navigational fix, data and receive further instructions for command and control. The glider is capable of storm sampling and can be flown in a coordinated fleet. It is 1.5 m in length, has a hull diameter of 22 cm and mass of 55-70 kgs (dependent upon configuration). It has an exchangeable payload (capacity up to 6 L) which is capable of housing a variety of environmental sensors such as nitrate and oxygen. It uses lithium or alkaline batteries. It has a deployment range of 350-13000 km (dependent upon configuration), a deployment length of 15 days to 18 months (dependent upon configuration) and an operating depth range of 4-1000m. Navigation is via GPS waypoints, a pressure and altimeter sensor. Maximum speed is 0.35 m/s (0.68 knot) with the buoyancy engine and an average up to 0.5 m/s (1 knots) with full drive. The thruster provides speeds up to 1 m/s (2 knots). It transmits via RF modem, Iridium (RUDICS), ARGOS or acoustic modem. The new STM32L4 CPU processor utilises OpenRTOS running up to 120 MHz, with 8 Mbytes RAM and 32 Mbytes of flash memory.
# 	 id : unit_1190
# 	 instruments : instrument_rbrctd,instrument_hydrophone,instrument_vmt
# 	 ioos_category : Identifier
# 	 long_name : Platform Metadata
# 	 maker : Teledyne Webb Research
# 	 maker_vocabulary : https://vocab.nerc.ac.uk/collection/L35/current/MAN0020/,https://vocab.nerc.ac.uk/collection/B75/current/ORG01077/
# 	 model : Teledyne Webb Research Slocum G3S glider
# 	 model_vocabulary : https://vocab.nerc.ac.uk/collection/B76/current/B7600029/
# 	 os_version : 11.01
# 	 owner : JASCO Applied Sciences
# 	 processing_level : 2
# 	 serial_number : 1190
# 	 type : sub-surface gliders
# 	 type_vocabulary : https://vocab.nerc.ac.uk/collection/L06/current/27/
# 	 units : 1
# 	 wmo_id : 8901118
# 	 wmo_platform_code : 8901118
# WMO ID:  4802987
# _NCProperties : version=2,netcdf=4.8.1,hdf5=1.12.2
# acknowledgement : This work was supported by funding from NOAA/IOOS/AOOS.
# cdm_data_type : TrajectoryProfile
# cdm_profile_variables : time_uv,lat_uv,lon_uv,u,v,profile_id,time,latitude,longitude
# cdm_trajectory_variables : trajectory,wmo_id
# comment : UAF G191 Glider deployment in the North Pacific Ocean (February 2025)A trajectory is one deployment of a glider.Sequential profile number within the trajectory.  This value is unique in each file that is part of a single trajectory/deployment.Timestamp corresponding to the mid-point of the profile.Value is interpolated to provide an estimate of the latitude at the mid-point of the profile.Value is interpolated to provide an estimate of the longitude at the mid-point of the profile.Slocum Glider UAF G191 -- pumped CTDSlocum Glider UAF G191The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.Glider pressure transducer measured pressureLatitude measured using on-board GPS.  NMEA coordinates.Longitude measured using on-board GPS. NMEA coordinates.Dead-reckoned latitude calculated by the glider while underwater. NMEA coordinatesDead-reckoned longitude calculoned by the glider while underwater. NMEA coordinatesInterpolated latitude at each point in the time-seriesInterpolated longitude at each point in the time-seriesTimestamp at each point in the time-seriesThe depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.The depth-averaged current is an estimate of the net current measured while the glider is underwater.  The value is calculated over the entire underwater segment, which may consist of 1 or more dives.
# contributor_email : sldanielson@alaska.edu
# contributor_name : Seth Danielson
# contributor_role : Principal Investigator
# contributor_url : https://www.uaf.edu/cfos/people/faculty/detail/seth-danielson.php
# Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# creator_email : hank.stats@alaska.edu
# creator_name : Hank Statscewich
# creator_url : https://uaf.edu/cfos/people/research-staff-and-post-docs/detail/hank-statscewich.php
# date_created : 2025-03-13T22:25:46Z
# date_issued : 2025-03-13T22:25:46Z
# date_modified : 2025-03-13T22:25:46Z
# Easternmost_Easting : -148.66764364871676
# featureType : TrajectoryProfile
# format_version : IOOS_Glider_NetCDF_v3.0-noqartod.nc
# geospatial_bounds : POLYGON ((58.967710 -148.670540, 58.967710 -148.665370, 58.963890 -148.665370, 58.963890 -148.670540, 58.967710 -148.670540))
# geospatial_lat_max : 59.96055407122976
# geospatial_lat_min : 58.965558628111204
# geospatial_lat_units : degrees_north
# geospatial_lon_max : -148.66764364871676
# geospatial_lon_min : -149.4982723109224
# geospatial_lon_units : degrees_east
# geospatial_vertical_max : 195.7587
# geospatial_vertical_min : 2.417013
# geospatial_vertical_positive : down
# geospatial_vertical_units : m
# gts_ingest : true
# history : 2025-03-13T22:25:46Z - Created with the GUTILS package: https://github.com/SECOORA/GUTILS
# id : unit_191-20250226T00004802987
# infoUrl : https://gliders.ioos.us/erddap/
# institution : The University of Alaska Fairbanks College of Fisheries and Ocean Science
# ioos_dac_checksum : 07a98a01cc86a7a958c7515fb4f0534c
# ioos_dac_completed : False
# ioos_regional_association : aoos
# keywords : AUVS > Autonomous Underwater Vehicles, Earth Science > Oceans > Ocean Pressure > Water Pressure, Earth Science > Oceans > Ocean Temperature > Water Temperature, Earth Science > Oceans > Salinity/Density > Conductivity, Earth Science > Oceans > Salinity/Density > Density, Earth Science > Oceans > Salinity/Density > Salinity, glider, In Situ Ocean-based platforms > Seaglider, Slocum, Spray, trajectory, underwater glider, water, wmo
# keywords_vocabulary : GCMD Science Keywords
# license : This data may be redistributed and used without restriction.
# Metadata_Conventions : Unidata Dataset Discovery v1.0, COARDS, CF-1.6
# naming_authority : edu.alaska
# Northernmost_Northing : 59.96055407122976
# platform_tags : portal:25,axds:portal:25:tag:Gliders
# platform_type : Slocum Glider
# processing_level : Dataset taken from glider native file format and is provided as is with no expressed or implied assurance of quality assurance or quality control.
# project : AOOS Gliders in Support of Fisheries Management
# publisher_email : dmac@aoos.org
# publisher_name : AOOS Glider Observatory
# publisher_url : https://aoos.org
# sea_name : North Pacific Ocean
# source : Observational data from a profiling glider
# sourceUrl : (local files)
# Southernmost_Northing : 58.965558628111204
# standard_name_vocabulary : CF-v25
# subsetVariables : wmo_id,trajectory,profile_id,time,latitude,longitude
# summary : UAF G191 Glider deployment in the North Pacific Ocean (February 2025)
# support_email : dmac@aoos.org,ioos.glider.data@noaa.gov,ioos.glider.data@noaa.gov
# support_name : aoos,ioos,noaa
# support_role : fiscal,fiscal,fiscal
# support_type : ra,federal,federal
# time_coverage_duration : P0DT0H21M46.292S
# time_coverage_end : 2025-03-13T19:19:02Z
# time_coverage_start : 2025-02-26T01:25:27Z
# title : unit_191-20250226T0000
# Westernmost_Easting : -149.4982723109224
# variable name:  instrument_ctd
# 	 _FillValue : 0
# 	 calibration_date : 2023
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 22
#      20 print ("variable name: ", vars)
#      21 for attribute in (var["Attribute Name"].dropna()):
# ---> 22     print ("\t", attribute, ":", "".join(var.loc[var["Attribute Name"] == attribute , "Value"]))
#
# TypeError: sequence item 0: expected str instance, float found
